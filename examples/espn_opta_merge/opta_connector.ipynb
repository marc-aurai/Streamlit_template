# %%
import requests
import datetime as dt
import pandas as pd

# %% [markdown]
# # Get all dates from competition:
# d1k1pqdg2yvw8e8my74yvrdw4 = 2022/2023

# %%
url = f'http://api.performfeeds.com/soccerdata/tournamentschedule/6bxvue6su4ev1690mzy62a41t/d1k1pqdg2yvw8e8my74yvrdw4?_rt=b&_fmt=json'

response = requests.get(url)
match_dates = response.json()['matchDate']

# %%
response.json()['competition']['name']
# Out:
# 'Eredivisie'

# %%
len(match_dates)
# Out:
# 96

# %%
df_matches = pd.DataFrame()
for idx_match_date in range(len(match_dates)):
    df_matches = pd.concat([df_matches, pd.DataFrame(match_dates[idx_match_date]['match'])])
df_matches_ = df_matches[['id','date','homeContestantId','awayContestantId',
                          'homeContestantOfficialName', 'awayContestantOfficialName',
                          'homeContestantName', 'awayContestantName','homeContestantCode','awayContestantCode',
                          ]]

# %%
df_matches.sort_values(by='date', ascending = False, inplace = True)
display(df_matches[70:90])
# Out:
#                           id coverageLevel optaBetting         date  \
# 3  3sgj0ovw218808x3rufw5yolw            15           1  2023-04-01Z
# 2  3s8zwzy76xvfuhvrmayrznnkk            15           1  2023-04-01Z
# 1  3ruc2qrojzhtif15kzz49vris            15           1  2023-04-01Z
# 1  3qqb1ugtdpy297ud1dzaxh3pw            15           1  2023-03-19Z
# 0  3r1k5dqrw10mnnl9pgq05cnbo            15           1  2023-03-19Z
# 2  3qu3jed75l0hqtr6wljncxses            15           1  2023-03-19Z
# 3  3rmkjoy5m1moo2gdbi1x0s6xg            15           1  2023-03-19Z
# 4  3r7900aaeot600500r7ta3thw            15           1  2023-03-19Z
# 2  3ripcv8bn1r5qlzf9z7ktsufo            15           1  2023-03-18Z
# 1  3qxse99ao4tt7wnal54l36xhw            15           1  2023-03-18Z
# 0  3rb088jsiak9zorqenhtyb8k4            15           1  2023-03-18Z
# 0  3res28ip6d7vd3qg50mogxno4            15           1  2023-03-17Z
# 2  3qeavkgpt9rjjetni8cp3v2ms            15           1  2023-03-12Z
# ...

# %% [markdown]
# # Perform merge on ESPN Scraped data

# %%
df_espn = pd.read_csv('../../espn_scraper/scraper_data/articles_28.csv', sep=";")
df_espn.sort_values(by='date', ascending = False, inplace = True)

df_merged = pd.merge(df_espn, df_matches_, how='left', left_on=['date', 'home_abbrev', 'away_abbrev'], right_on=['date', 'homeContestantCode', 'awayContestantCode'])

# %%
display(df_merged)
# Out:
#     Unnamed: 0  espn_id              home_team              away_team  \
# 0           24   637424              FC Twente                     AZ
# 1           23   637423           FC Groningen          sc Heerenveen
# 2           20   637420                   Ajax              Feyenoord
# 3           27   637427           RKC Waalwijk                 N.E.C.
# 4           25   637425             FC Utrecht        Go Ahead Eagles
# 5           22   637422               FC Emmen       Sparta Rotterdam
# 6           16   637416                 N.E.C.             FC Utrecht
# 7           19   637419          sc Heerenveen                   Ajax
# 8           17   637417                    PSV  SC Cambuur Leeuwarden
# 9           13   637413              Feyenoord            FC Volendam
# 10          18   637418       Sparta Rotterdam                Vitesse
# 11          14   637414        Fortuna Sittard              FC Twente
# ...

# %% [markdown]
# # Get all Eredivisie ID's / Year / Startdate

# %%
competetions = requests.get(f'https://api.performfeeds.com/soccerdata/tournamentcalendar/6bxvue6su4ev1690mzy62a41t?_rt=b&_fmt=json')
print(competetions.json().keys())
# Out:
# dict_keys(['competition', 'lastUpdated'])

# %%
for competetion in competetions.json()['competition']:
    if competetion['name'] == "Eredivisie":
        for eredivisie in competetion['tournamentCalendar']:
            print(eredivisie['id'], eredivisie['name'], eredivisie['startDate'], eredivisie['endDate'])
# Out:
# d1k1pqdg2yvw8e8my74yvrdw4 2022/2023 2022-08-05Z 2023-06-11Z
# dp0vwa5cfgx2e733gg98gfhg4 2021/2022 2021-08-13Z 2022-05-29Z
# bp1sjjiswd4t3nw86vf6yq7hm 2020/2021 2020-09-12Z 2021-05-23Z
# 84u7auf89eo1kvtnitmq9dizu 2019/2020 2019-08-02Z 2020-05-10Z
# dk9v47m40z7lccjlyzhh4wsx6 2018/2019 2018-08-10Z 2019-05-28Z
# c8zlmv1tc08kux34sown7lujt 2017/2018 2017-08-11Z 2018-05-19Z
# 8az4xxa1x98n0y43huxmaavop 2016/2017 2016-08-05Z 2017-05-28Z
# 3aeaqiwjhvk4ikz8ureupe7zd 2015/2016 2015-08-08Z 2016-05-22Z
# f2s2aqubjnif16x7nu49ys34l 2014/2015 2014-08-08Z 2015-05-31Z
# 1d6uztze49i5ax5yfhyci4ety 2013/2014 2013-08-02Z 2014-05-18Z
# 2yw9i8g16s9ea8o9bz1yb1xw5 2012/2013 2012-08-10Z 2013-05-26Z
# 7zyxizjd67w6enggjhh14lo0l 2011/2012 2011-08-05Z 2012-05-20Z
# 54gb7216sceezre3sp4fy8zpx 2010/2011 2010-08-06Z 2011-05-29Z
# aas11zaonw7teauv3shyx0ez9 2009/2010 2009-07-31Z 2010-05-16Z
# 2jco8lkk1i8x6ze25zano56mt 2008/2009 2008-08-29Z 2009-05-31Z
# 83um23yr6fe1zh3hs1zsexb6d 2007/2008 2007-08-17Z 2008-05-18Z
# ...

# %%
df_tournament_opta = pd.read_csv("../../opta/data/tournamentschedule_Eredivisie.csv", sep=";")
df_tournament_opta.head()
# Out:
#    Unnamed: 0                         id         date  \
# 0           0  3xp5uvef2i0z40glz9qq7f85w  2022-08-05Z
# 1           1  3xtddwq4558vjrh84uh6vxj4k  2022-08-06Z
# 2           2  3xvysgmver498fdhvugbuhd04  2022-08-06Z
# 3           3  3xyl0qt0lpr25p5onwmdqqal0  2022-08-06Z
# 4           4  3y15kr81sa8wpz5j6fhvi3wno  2022-08-06Z
#
#             homeContestantId           awayContestantId  \
# 0  4vd2t5schmvvufrfib7f2vjdf  89w5c6pw7vn0dxypi61tt0g4k
# 1  3ebril33e08ddzob4bhq8awsr  d0zdg647gvgc95xdtk1vpbkys
# 2  ears40cp6opsgvhsy0dgyszpd  dqk062lu0vm8epvytbm6r4mmf
# 3  24fvcruwqrqvqa3aonf8c3zuy  3t0vjqtxc8wpjzv82i3oi2ova
# 4  ed5nwjz5za3oyi20nxzgqivmx  ccpscwdcm65czscrun048ecn5
#
#   homeContestantOfficialName awayContestantOfficialName homeContestantCode  \
# 0              SC Heerenveen           Sparta Rotterdam                HEE
# 1            Fortuna Sittard                   AFC Ajax                FOR
# ...

# %% [markdown]
# # Get matchstats

# %%
match_id = "3qiazt6i0ois333dgtt9o6tck"# 3oq6iggjm5jj15z1ngsfmdgd0
matchstats = requests.get(f'http://api.performfeeds.com/soccerdata/matchstats/6bxvue6su4ev1690mzy62a41t/?_rt=b&_fmt=json&fx={{}}'.format(match_id)).json()['liveData']['goal']
#print(matchstats['liveData'].keys())

# %%
for goal in matchstats:
    team = requests.get(f'http://api.performfeeds.com/soccerdata/team/6bxvue6su4ev1690mzy62a41t/?_rt=b&_fmt=json&ctst={{}}'.format(goal['contestantId'])).json()['contestant'][0]['name']
    print(team, goal["contestantId"],
                    goal["periodId"],
                    goal["timeMin"],
                    goal["scorerName"])
# Out:
# Ajax d0zdg647gvgc95xdtk1vpbkys 1 10 M. Kudus
# Ajax d0zdg647gvgc95xdtk1vpbkys 1 16 E. Álvarez
# Ajax d0zdg647gvgc95xdtk1vpbkys 1 19 S. Bergwijn
# Heerenveen 4vd2t5schmvvufrfib7f2vjdf 1 42 P. van Amersfoort
# Ajax d0zdg647gvgc95xdtk1vpbkys 2 52 K. Taylor
# Heerenveen 4vd2t5schmvvufrfib7f2vjdf 2 79 S. van Hooijdonk

# %%
team = [[requests.get(f'http://api.performfeeds.com/soccerdata/team/6bxvue6su4ev1690mzy62a41t/?_rt=b&_fmt=json&ctst={{}}'.format(goal['contestantId'])).json()['contestant'][0]['name'], goal["contestantId"], goal['periodId'], goal['timeMin'], goal['scorerName']] for goal in matchstats]
team
# Out:
# [['Ajax', 'd0zdg647gvgc95xdtk1vpbkys', 1, 10, 'M. Kudus'],
#  ['Ajax', 'd0zdg647gvgc95xdtk1vpbkys', 1, 16, 'E. Álvarez'],
#  ['Ajax', 'd0zdg647gvgc95xdtk1vpbkys', 1, 19, 'S. Bergwijn'],
#  ['Heerenveen', '4vd2t5schmvvufrfib7f2vjdf', 1, 42, 'P. van Amersfoort'],
#  ['Ajax', 'd0zdg647gvgc95xdtk1vpbkys', 2, 52, 'K. Taylor'],
#  ['Heerenveen', '4vd2t5schmvvufrfib7f2vjdf', 2, 79, 'S. van Hooijdonk']]

# %%
df_events = pd.DataFrame(team, columns=['goal_team','goal_contestantId','goal_period','goal_time','goal_player'])
df_events
# Out:
#     goal_team          goal_contestantId  goal_period  goal_time  \
# 0        Ajax  d0zdg647gvgc95xdtk1vpbkys            1         10
# 1        Ajax  d0zdg647gvgc95xdtk1vpbkys            1         16
# 2        Ajax  d0zdg647gvgc95xdtk1vpbkys            1         19
# 3  Heerenveen  4vd2t5schmvvufrfib7f2vjdf            1         42
# 4        Ajax  d0zdg647gvgc95xdtk1vpbkys            2         52
# 5  Heerenveen  4vd2t5schmvvufrfib7f2vjdf            2         79
#
#          goal_player
# 0           M. Kudus
# 1         E. Álvarez
# 2        S. Bergwijn
# 3  P. van Amersfoort
# 4          K. Taylor
# 5   S. van Hooijdonk

# %%
events_ajax = df_events.loc[df_events['goal_contestantId'] == "d0zdg647gvgc95xdtk1vpbkys"].values.tolist()

# %%
events_ajax
# Out:
# [['Ajax', 'd0zdg647gvgc95xdtk1vpbkys', 1, 10, 'M. Kudus'],
#  ['Ajax', 'd0zdg647gvgc95xdtk1vpbkys', 1, 16, 'E. Álvarez'],
#  ['Ajax', 'd0zdg647gvgc95xdtk1vpbkys', 1, 19, 'S. Bergwijn'],
#  ['Ajax', 'd0zdg647gvgc95xdtk1vpbkys', 2, 52, 'K. Taylor']]

# %% [markdown]
# # Delete unnamed columns

# %%
df_opta_merged = pd.read_csv("../../opta/data/merged/merged_tournamentschedule.csv", sep=";")
df_opta_merged.drop(df_opta_merged.filter(regex="Unname"),axis=1, inplace=True)
df_opta_merged[:1]
# Out:
#    espn_id home_team    away_team home_abbrev away_abbrev  score_home  \
# 0   637400    N.E.C.  FC Volendam      N.E.C.         VOL           3
#
#    score_away date                                   cup article_title  \
# 0           0  NaN  2022-23 Eredivisie, Regulier seizoen           NaN
#
#   article   id homeContestantId awayContestantId homeContestantOfficialName  \
# 0     NaN  NaN              NaN              NaN                        NaN
#
#   awayContestantOfficialName homeContestantCode awayContestantCode  \
# 0                        NaN                NaN                NaN
#
#   card_events goal_events
# 0         NaN         NaN

# %%
print(df_opta_merged.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   espn_id                     27 non-null     int64
#  1   home_team                   27 non-null     object
#  2   away_team                   27 non-null     object
#  3   home_abbrev                 27 non-null     object
#  4   away_abbrev                 27 non-null     object
#  5   score_home                  27 non-null     int64
#  6   score_away                  27 non-null     int64
#  7   date                        22 non-null     object
#  8   cup                         27 non-null     object
#  9   article_title               22 non-null     object
#  10  article                     22 non-null     object
#  11  id                          22 non-null     object
#  12  homeContestantId            22 non-null     object
# ...
