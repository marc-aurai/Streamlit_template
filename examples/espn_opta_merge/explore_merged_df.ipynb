# %%
import pandas as pd

# %%
df_merged = pd.read_csv("../../opta/data/merged/merged_tournamentschedule.csv", sep=";")

# %%
#pd.set_option('display.max_colwidth', None)
df_merged[10:20]
# Out:
#     Unnamed: 0  espn_id         home_team              away_team home_abbrev  \
# 10          10   637410       FC Volendam               FC Emmen         VOL
# 11          11   637411                AZ           FC Groningen          AZ
# 12          12   637412          FC Emmen              Excelsior         EMM
# 13          13   637413         Feyenoord            FC Volendam         FEY
# 14          14   637414   Fortuna Sittard              FC Twente         FOR
# 15          15   637416            N.E.C.             FC Utrecht      N.E.C.
# 16          16   637417               PSV  SC Cambuur Leeuwarden         PSV
# 17          17   637418  Sparta Rotterdam                Vitesse         SPA
# 18          18   637419     sc Heerenveen                   Ajax         HEE
# 19          19   637420              Ajax              Feyenoord         AJA
#
#    away_abbrev  score_home  score_away         date  \
# 10         EMM           3           1  2023-03-04Z
# ...
